# %%
print('hi')
# Out:
# hi

# %%
print("abhi'\\\\\\\\\\\\\\\\")
# Out:
# abhi'\\\\\\\\

# %%
print("BOT: WHAT IS YOUR NAME?")
user_name = input()
# Out:
# BOT: WHAT IS YOUR NAME?

# %%
# Out:
# first 20 prime no are
#
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21308\1141553801.py in <module>
#       4     print(2)
#       5 for c in range(2,n):
# ----> 6     for j in range(2,i):
#       7         if i%j==0:
#       8             break
#
# NameError: name 'i' is not defined

# %%
import random

def guess_the_number():
    print("Welcome to Guess the Number!")
    secret_number = random.randint(1, 100)
    guess_count = 0
    while True:
        guess = input("Guess a number between 1 and 100: ")
        if not guess.isdigit():
            print("Invalid input, please enter a number.")
            continue
        guess = int(guess)
        guess_count += 1
        if guess < secret_number:
            print("Too low, try again.")
        elif guess > secret_number:
            print("Too high, try again.")
        else:
            print(f"Congratulations, you guessed the number in {guess_count} tries!")
            break

# %%
class cs_engineer:
    name=""
    designatioin=""
    salary=""
    def prin(self):
        print("name:",self.name, "designation:",self.designatioin, "sallary:", self.salary)
        
    def __init__(self,name, designation,salary):
        self.name=name 
        self.designatioin=designation
        self.salary=salary


class mechanical_engineer:
    name=""
    designatioin=""
    salary=""
    def prin(self):
      print("name:",self.name, "designation:",self.designatioin, "sallary:", self.salary)
    
    def __init__(self,name, designation,salary):
        self.name=name 
        self.designatioin=designation
        self.salary=salary

    
class civil_engineer:
    name=""
    designatioin=""
    salary=""
    def prin(self):
       print("name:",self.name, "designation:",self.designatioin, "sallary:", self.salary)

    def __init__(self,name, designation,salary):
        self.name=name 
        self.designatioin=designation
        self.salary=salary


class electronics_engineer:
    name=""
    designatioin=""
    salary=""
    def prin(self):
        print("name:",self.name, "designation:",self.designatioin, "sallary:", self.salary)
    
    def __init__(self,name, designation,salary):
        self.name=name 
        self.designatioin=designation
        self.salary=salary


class electrical_engineer:
    name=""
    designatioin=""
    salary=""
    def prin(self):
        print("name:",self.name, "designation:",self.designatioin, "sallary:", self.salary)



    def __init__(self,name, designation,salary):
        self.name=name 
        self.designatioin=designation
        self.salary=salary



obj=cs_engineer('vinayak','cs engineer',"50000")
obj.prin()
obj=mechanical_engineer('vijay','mechanical engineer',"35000")
obj.prin()
obj=civil_engineer('chandrakant',' civil engineer',"25000")
obj.prin()
obj=electronics_engineer('shankar','electronics engineer',"40000")
obj.prin()

obj=electrical_engineer('sanjay','electrical  engineer',"45000")
obj.prin()
# Out:
# name: vinayak designation: cs engineer sallary: 50000
# name: vijay designation: mechanical engineer sallary: 35000
# name: chandrakant designation:  civil engineer sallary: 25000
# name: shankar designation: electronics engineer sallary: 40000
# name: sanjay designation: electrical  engineer sallary: 45000

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=[80,90,60,50]

plt.pie(data,labels={'sub','sub2','sub3','sub4',},autopct='%1.1f%%')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = [80, 90, 60, 50]
labels = ['sub', 'sub2', 'sub3', 'sub4']

plt.pie(data, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14556\1191655368.py in <module>
# ----> 1 plt.scatter(df['income'], df['age'])
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

income= [4500, 1200, 7000, 2000],
age= [26, 35, 30, 47]
income1= [4800, 1000, 6000, 2600],
age1= [20, 33, 37, 48]


plt.scatter(income,age,marker="*",c="red")
plt.scatter(income1,age1,marker="^",c="blue")
plt.xlabel("income")
plt.xlabel("income1")

plt.ylabel("age")
plt.ylabel("age1")

plt.show()

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

k=np.arange(0,16)
x=np.cos(2*k*np.pi/4)
plt.stem(k,x,use_line_collection=True)
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt

vec=np.array([[-3],[2]])
origin=np.zeros(vec.shape)

plt.figure(figsize=(6,6))
plt.quiver(*origin,*vec,color=['b'],scale=1,units='xy')

plt.grid()
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.gca().set_aspect('equal')
plt.show()

# %%
l1 = [1, 7, 4, 3, 4, 8, 7]
N = len(l1)
k = 2

for num in l1:
    count = l1.count(num)
    print(f"The number {num} appears {count} times in the list.")
# Out:
# The number 1 appears 1 times in the list.
# The number 7 appears 2 times in the list.
# The number 4 appears 2 times in the list.
# The number 3 appears 1 times in the list.
# The number 4 appears 2 times in the list.
# The number 8 appears 1 times in the list.
# The number 7 appears 2 times in the list.

# %%
l1 = [1, 7, 4, 3, 4, 8, 7]

N = len(l1)
k = 2

for num in l1:
    count = l1.count(num)
    if num==4:
        
        print("Answer:",num)
        break
# Out:
# Answer: 4
